# %% [markdown]
# # Creating a Deep Model to predict the antidepressant effect

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import f_classif

import nibabel as nib
import matplotlib.pyplot as plt # For data viz
import pandas as pd
import numpy as np
import sys

print('System Version:', sys.version)
print('PyTorch version', torch.__version__)
print('Numpy version', np.__version__)
print('Pandas version', pd.__version__)
# Out:
# System Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version 2.5.1
# Numpy version 1.26.4
# Pandas version 2.2.3

# %%
# Confirm device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
try: 
    name = torch.cuda.get_device_name(0)
    count = torch.cuda.device_count()
    print(f"Device count: {count}")
    print(f"Device name: {name}")
except RuntimeError:
    print('No GPUs detected')
# Out:
# Using cuda device
# Device count: 1
# Device name: NVIDIA L40S

# %%
# Load the data
X_train = np.load('data/X_SYN.npy')
X_test = np.load('data/X_TEST_RAW.npy')

y_train = np.load('data/y_SYN.npy')
y_test = np.load('data/y_TEST_RAW.npy')

# %%
X_train = X_train.reshape(X_train.shape[0], -1)  # Shape: (n, 91*109*91)
X_test = X_test.reshape(X_test.shape[0], -1)  # Shape: (n, 91*109*91)

# Generate the index mapping
# First, create all combinations of indices for the last 3 dims
sub_indices = np.indices((91, 109, 91)).reshape(3, -1).T  # Shape: (91*109*91, 3)

# Now tile this across the first dimension (39)
num_per_outer = sub_indices.shape[0]  # 91*109*91
outer_indices = np.repeat(np.arange(39), num_per_outer).reshape(-1, 1)  # Shape: (39*num_per_outer, 1)

# Repeat sub_indices for each outer index
all_indices = np.hstack([outer_indices, np.tile(sub_indices, (39, 1))])  # Shape: (39*num_per_outer, 4)
locs = np.delete(all_indices, 0, axis=1)


# Select top k voxels with highest mutual information
k = 100  # amount of voxels to keep
selector = SelectKBest(score_func=f_classif, k=k)
selector.fit(X_train, y_train)

# Transform both the training and test data using the fitted selector
X_train = selector.transform(X_train)
X_test = selector.transform(X_test)

# flatten the data for when not using feature selection
#X_train = X_train.flatten()
#X_test = X_test.flatten()

# %%
# Load reference NIfTI file (to get shape and affine)
ref_file = 'masks/MVP_rois/amygdalawhole_thr50_2mm.nii.gz'
ref_img = nib.load(ref_file)
ref_shape = ref_img.shape
ref_affine = ref_img.affine


# Get indices of selected voxels
selected_voxel_indices = selector.get_support(indices=True)

# === Save mask of selected voxels ===
# Create an empty mask with the same shape as reference
mask_data = np.zeros(ref_shape, dtype=np.uint8)

# Matrix of coordinates (assumed in voxel space)
locations_voxel = locs[selected_voxel_indices]

# Populate the mask
for xc, yc, zc in locations_voxel:
    if 0 <= xc < ref_shape[0] and 0 <= yc < ref_shape[1] and 0 <= zc < ref_shape[2]:
        mask_data[int(xc), int(yc), int(zc)] = 1

# Create a new NIfTI image
mask_img = nib.Nifti1Image(mask_data, affine=ref_affine)

# Save to disk
print('Saving mask to disk....')
nib.save(mask_img, 'masks/mask_selected_voxels.nii.gz')
print('DONE')
# Out:
# Saving mask to disk....
# DONE

# %%
print(X_train.shape)
# Out:
# (409, 100)

# %%
# Define the dataset
class COPEDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        cope_data = self.data[index]
        if (np.max(cope_data) - np.min(cope_data)) == 0:
            print('No variation')
            print(np.max(cope_data))
        cope_data = (cope_data - np.min(cope_data)) / (np.max(cope_data) - np.min(cope_data))  # normalize

        label = self.target[index]
        volume = torch.tensor(cope_data, dtype=torch.float32).unsqueeze(0)  # (1, 91, 109, 91)
        label = torch.tensor([1.0, 0.0] if label == 0 else [0.0, 1.0], dtype=torch.float32)
        return volume, label

# %%
# Initiate the dataset and data loader
train_dataset = COPEDataset(X_train, y_train)
test_dataset = COPEDataset(X_test, y_test)
train_dataloader = DataLoader(train_dataset, batch_size=10)
test_dataloader = DataLoader(test_dataset)

# %%
class BrainClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, num_classes),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Setup
# Example usage:
input_size = k
hidden_size = 3000
num_classes = 2

# Create an instance of the model
#torch.manual_seed(117)
model = BrainClassifier(input_size, hidden_size, num_classes).cuda()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()

# Train
for epoch in range(300):
    model.train()
    total_loss, correct = 0.0, 0

    for batch in train_dataloader:
        inputs, labels = batch
        inputs, labels = inputs.cuda(), labels.cuda()

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == torch.argmax(labels, dim=1)).sum().item()

    acc = correct / len(train_dataloader.dataset)
    print(f"Epoch {epoch+1}, Loss: {total_loss:.2f}, Accuracy: {acc:.4f}")
# Out:
# Epoch 1, Loss: 62.79, Accuracy: 0.6088
# Epoch 2, Loss: 30.24, Accuracy: 0.2885
# Epoch 3, Loss: 30.45, Accuracy: 0.3399
# Epoch 4, Loss: 29.93, Accuracy: 0.2763
# Epoch 5, Loss: 29.89, Accuracy: 0.3227
# Epoch 6, Loss: 30.91, Accuracy: 0.3130
# Epoch 7, Loss: 30.29, Accuracy: 0.3301
# Epoch 8, Loss: 29.15, Accuracy: 0.3961
# Epoch 9, Loss: 30.54, Accuracy: 0.3692
# Epoch 10, Loss: 28.26, Accuracy: 0.4499
# Epoch 11, Loss: 30.42, Accuracy: 0.4377
# Epoch 12, Loss: 26.45, Accuracy: 0.5697
# Epoch 13, Loss: 29.83, Accuracy: 0.4988
# Epoch 14, Loss: 24.30, Accuracy: 0.7017
# Epoch 15, Loss: 25.59, Accuracy: 0.6381
# Epoch 16, Loss: 23.99, Accuracy: 0.6944
# Epoch 17, Loss: 19.56, Accuracy: 0.7751
# Epoch 18, Loss: 21.70, Accuracy: 0.7335
# Epoch 19, Loss: 18.20, Accuracy: 0.7971
# Epoch 20, Loss: 15.51, Accuracy: 0.8240
# Epoch 21, Loss: 15.66, Accuracy: 0.8289
# Epoch 22, Loss: 13.82, Accuracy: 0.8582
# Epoch 23, Loss: 12.15, Accuracy: 0.8729
# Epoch 24, Loss: 11.14, Accuracy: 0.8778
# Epoch 25, Loss: 10.30, Accuracy: 0.8900
# Epoch 26, Loss: 9.50, Accuracy: 0.8998
# Epoch 27, Loss: 8.66, Accuracy: 0.9144
# Epoch 28, Loss: 7.94, Accuracy: 0.9291
# Epoch 29, Loss: 7.39, Accuracy: 0.9438
# Epoch 30, Loss: 6.87, Accuracy: 0.9487
# Epoch 31, Loss: 6.30, Accuracy: 0.9487
# Epoch 32, Loss: 5.83, Accuracy: 0.9560
# Epoch 33, Loss: 5.39, Accuracy: 0.9560
# Epoch 34, Loss: 5.02, Accuracy: 0.9560
# Epoch 35, Loss: 4.66, Accuracy: 0.9609
# Epoch 36, Loss: 4.30, Accuracy: 0.9658
# Epoch 37, Loss: 3.96, Accuracy: 0.9682
# Epoch 38, Loss: 3.64, Accuracy: 0.9682
# Epoch 39, Loss: 3.40, Accuracy: 0.9682
# Epoch 40, Loss: 3.07, Accuracy: 0.9731
# Epoch 41, Loss: 2.90, Accuracy: 0.9731
# Epoch 42, Loss: 2.65, Accuracy: 0.9780
# Epoch 43, Loss: 2.47, Accuracy: 0.9780
# Epoch 44, Loss: 2.21, Accuracy: 0.9853
# Epoch 45, Loss: 2.02, Accuracy: 0.9853
# Epoch 46, Loss: 1.74, Accuracy: 0.9853
# Epoch 47, Loss: 1.53, Accuracy: 0.9878
# Epoch 48, Loss: 1.37, Accuracy: 0.9878
# Epoch 49, Loss: 1.22, Accuracy: 0.9853
# Epoch 50, Loss: 1.10, Accuracy: 0.9878
# Epoch 51, Loss: 0.83, Accuracy: 0.9902
# Epoch 52, Loss: 0.63, Accuracy: 0.9951
# Epoch 53, Loss: 0.53, Accuracy: 0.9951
# Epoch 54, Loss: 0.51, Accuracy: 0.9951
# Epoch 55, Loss: 0.48, Accuracy: 0.9951
# Epoch 56, Loss: 0.44, Accuracy: 0.9951
# Epoch 57, Loss: 0.38, Accuracy: 0.9951
# Epoch 58, Loss: 0.32, Accuracy: 0.9951
# Epoch 59, Loss: 0.29, Accuracy: 0.9951
# Epoch 60, Loss: 0.26, Accuracy: 0.9951
# Epoch 61, Loss: 0.24, Accuracy: 0.9951
# Epoch 62, Loss: 0.22, Accuracy: 0.9951
# Epoch 63, Loss: 0.21, Accuracy: 0.9976
# Epoch 64, Loss: 0.20, Accuracy: 0.9976
# Epoch 65, Loss: 0.19, Accuracy: 0.9976
# Epoch 66, Loss: 0.18, Accuracy: 0.9976
# Epoch 67, Loss: 0.18, Accuracy: 0.9976
# Epoch 68, Loss: 0.17, Accuracy: 0.9976
# Epoch 69, Loss: 0.16, Accuracy: 0.9976
# Epoch 70, Loss: 0.16, Accuracy: 0.9976
# Epoch 71, Loss: 0.15, Accuracy: 0.9976
# Epoch 72, Loss: 0.14, Accuracy: 0.9976
# Epoch 73, Loss: 0.14, Accuracy: 0.9976
# Epoch 74, Loss: 0.13, Accuracy: 1.0000
# Epoch 75, Loss: 0.13, Accuracy: 1.0000
# Epoch 76, Loss: 0.12, Accuracy: 1.0000
# Epoch 77, Loss: 0.12, Accuracy: 1.0000
# Epoch 78, Loss: 0.11, Accuracy: 1.0000
# Epoch 79, Loss: 0.11, Accuracy: 1.0000
# Epoch 80, Loss: 0.11, Accuracy: 1.0000
# Epoch 81, Loss: 0.10, Accuracy: 1.0000
# Epoch 82, Loss: 0.10, Accuracy: 1.0000
# Epoch 83, Loss: 0.09, Accuracy: 1.0000
# Epoch 84, Loss: 0.09, Accuracy: 1.0000
# Epoch 85, Loss: 0.09, Accuracy: 1.0000
# Epoch 86, Loss: 0.09, Accuracy: 1.0000
# Epoch 87, Loss: 0.08, Accuracy: 1.0000
# Epoch 88, Loss: 0.08, Accuracy: 1.0000
# Epoch 89, Loss: 0.07, Accuracy: 1.0000
# Epoch 90, Loss: 0.07, Accuracy: 1.0000
# Epoch 91, Loss: 0.07, Accuracy: 1.0000
# Epoch 92, Loss: 0.07, Accuracy: 1.0000
# Epoch 93, Loss: 0.06, Accuracy: 1.0000
# Epoch 94, Loss: 0.06, Accuracy: 1.0000
# Epoch 95, Loss: 0.06, Accuracy: 1.0000
# Epoch 96, Loss: 0.06, Accuracy: 1.0000
# Epoch 97, Loss: 0.05, Accuracy: 1.0000
# Epoch 98, Loss: 0.05, Accuracy: 1.0000
# Epoch 99, Loss: 0.05, Accuracy: 1.0000
# Epoch 100, Loss: 0.05, Accuracy: 1.0000
# Epoch 101, Loss: 0.04, Accuracy: 1.0000
# Epoch 102, Loss: 0.04, Accuracy: 1.0000
# Epoch 103, Loss: 0.04, Accuracy: 1.0000
# Epoch 104, Loss: 0.04, Accuracy: 1.0000
# Epoch 105, Loss: 0.04, Accuracy: 1.0000
# Epoch 106, Loss: 0.03, Accuracy: 1.0000
# Epoch 107, Loss: 0.03, Accuracy: 1.0000
# Epoch 108, Loss: 0.03, Accuracy: 1.0000
# Epoch 109, Loss: 0.03, Accuracy: 1.0000
# Epoch 110, Loss: 0.03, Accuracy: 1.0000
# Epoch 111, Loss: 0.03, Accuracy: 1.0000
# Epoch 112, Loss: 0.02, Accuracy: 1.0000
# Epoch 113, Loss: 0.02, Accuracy: 1.0000
# Epoch 114, Loss: 0.02, Accuracy: 1.0000
# Epoch 115, Loss: 0.02, Accuracy: 1.0000
# Epoch 116, Loss: 0.02, Accuracy: 1.0000
# Epoch 117, Loss: 0.02, Accuracy: 1.0000
# Epoch 118, Loss: 0.02, Accuracy: 1.0000
# Epoch 119, Loss: 0.02, Accuracy: 1.0000
# Epoch 120, Loss: 0.02, Accuracy: 1.0000
# Epoch 121, Loss: 0.01, Accuracy: 1.0000
# Epoch 122, Loss: 0.01, Accuracy: 1.0000
# Epoch 123, Loss: 0.01, Accuracy: 1.0000
# Epoch 124, Loss: 0.01, Accuracy: 1.0000
# Epoch 125, Loss: 0.01, Accuracy: 1.0000
# Epoch 126, Loss: 0.01, Accuracy: 1.0000
# Epoch 127, Loss: 0.01, Accuracy: 1.0000
# Epoch 128, Loss: 0.01, Accuracy: 1.0000
# Epoch 129, Loss: 0.01, Accuracy: 1.0000
# Epoch 130, Loss: 0.01, Accuracy: 1.0000
# Epoch 131, Loss: 0.01, Accuracy: 1.0000
# Epoch 132, Loss: 0.01, Accuracy: 1.0000
# Epoch 133, Loss: 0.01, Accuracy: 1.0000
# Epoch 134, Loss: 0.01, Accuracy: 1.0000
# Epoch 135, Loss: 0.01, Accuracy: 1.0000
# Epoch 136, Loss: 0.01, Accuracy: 1.0000
# Epoch 137, Loss: 0.01, Accuracy: 1.0000
# Epoch 138, Loss: 0.01, Accuracy: 1.0000
# Epoch 139, Loss: 0.01, Accuracy: 1.0000
# Epoch 140, Loss: 0.01, Accuracy: 1.0000
# Epoch 141, Loss: 0.01, Accuracy: 1.0000
# Epoch 142, Loss: 0.01, Accuracy: 1.0000
# Epoch 143, Loss: 0.00, Accuracy: 1.0000
# Epoch 144, Loss: 0.00, Accuracy: 1.0000
# Epoch 145, Loss: 0.00, Accuracy: 1.0000
# Epoch 146, Loss: 0.00, Accuracy: 1.0000
# Epoch 147, Loss: 0.00, Accuracy: 1.0000
# Epoch 148, Loss: 0.00, Accuracy: 1.0000
# Epoch 149, Loss: 0.00, Accuracy: 1.0000
# Epoch 150, Loss: 0.00, Accuracy: 1.0000
# Epoch 151, Loss: 0.00, Accuracy: 1.0000
# Epoch 152, Loss: 0.00, Accuracy: 1.0000
# Epoch 153, Loss: 0.00, Accuracy: 1.0000
# Epoch 154, Loss: 0.00, Accuracy: 1.0000
# Epoch 155, Loss: 0.00, Accuracy: 1.0000
# Epoch 156, Loss: 0.00, Accuracy: 1.0000
# Epoch 157, Loss: 0.00, Accuracy: 1.0000
# Epoch 158, Loss: 0.00, Accuracy: 1.0000
# Epoch 159, Loss: 0.00, Accuracy: 1.0000
# Epoch 160, Loss: 0.00, Accuracy: 1.0000
# Epoch 161, Loss: 0.00, Accuracy: 1.0000
# Epoch 162, Loss: 0.00, Accuracy: 1.0000
# Epoch 163, Loss: 0.00, Accuracy: 1.0000
# Epoch 164, Loss: 0.00, Accuracy: 1.0000
# Epoch 165, Loss: 0.00, Accuracy: 1.0000
# Epoch 166, Loss: 0.00, Accuracy: 1.0000
# Epoch 167, Loss: 0.00, Accuracy: 1.0000
# Epoch 168, Loss: 0.00, Accuracy: 1.0000
# Epoch 169, Loss: 0.00, Accuracy: 1.0000
# Epoch 170, Loss: 0.00, Accuracy: 1.0000
# Epoch 171, Loss: 0.00, Accuracy: 1.0000
# Epoch 172, Loss: 0.00, Accuracy: 1.0000
# Epoch 173, Loss: 0.00, Accuracy: 1.0000
# Epoch 174, Loss: 0.00, Accuracy: 1.0000
# Epoch 175, Loss: 0.00, Accuracy: 1.0000
# Epoch 176, Loss: 0.00, Accuracy: 1.0000
# Epoch 177, Loss: 0.00, Accuracy: 1.0000
# Epoch 178, Loss: 0.00, Accuracy: 1.0000
# Epoch 179, Loss: 0.00, Accuracy: 1.0000
# Epoch 180, Loss: 0.00, Accuracy: 1.0000
# Epoch 181, Loss: 0.00, Accuracy: 1.0000
# Epoch 182, Loss: 0.00, Accuracy: 1.0000
# Epoch 183, Loss: 0.00, Accuracy: 1.0000
# Epoch 184, Loss: 0.00, Accuracy: 1.0000
# Epoch 185, Loss: 0.00, Accuracy: 1.0000
# Epoch 186, Loss: 0.00, Accuracy: 1.0000
# Epoch 187, Loss: 0.00, Accuracy: 1.0000
# Epoch 188, Loss: 0.00, Accuracy: 1.0000
# Epoch 189, Loss: 0.00, Accuracy: 1.0000
# Epoch 190, Loss: 0.00, Accuracy: 1.0000
# Epoch 191, Loss: 0.00, Accuracy: 1.0000
# Epoch 192, Loss: 0.00, Accuracy: 1.0000
# Epoch 193, Loss: 0.00, Accuracy: 1.0000
# Epoch 194, Loss: 0.00, Accuracy: 1.0000
# Epoch 195, Loss: 0.00, Accuracy: 1.0000
# Epoch 196, Loss: 0.00, Accuracy: 1.0000
# Epoch 197, Loss: 0.00, Accuracy: 1.0000
# Epoch 198, Loss: 0.00, Accuracy: 1.0000
# Epoch 199, Loss: 0.00, Accuracy: 1.0000
# Epoch 200, Loss: 0.00, Accuracy: 1.0000
# Epoch 201, Loss: 0.00, Accuracy: 1.0000
# Epoch 202, Loss: 0.00, Accuracy: 1.0000
# Epoch 203, Loss: 0.00, Accuracy: 1.0000
# Epoch 204, Loss: 0.00, Accuracy: 1.0000
# Epoch 205, Loss: 0.00, Accuracy: 1.0000
# Epoch 206, Loss: 0.00, Accuracy: 1.0000
# Epoch 207, Loss: 0.00, Accuracy: 1.0000
# Epoch 208, Loss: 0.00, Accuracy: 1.0000
# Epoch 209, Loss: 0.00, Accuracy: 1.0000
# Epoch 210, Loss: 0.00, Accuracy: 1.0000
# Epoch 211, Loss: 0.00, Accuracy: 1.0000
# Epoch 212, Loss: 0.00, Accuracy: 1.0000
# Epoch 213, Loss: 0.00, Accuracy: 1.0000
# Epoch 214, Loss: 0.00, Accuracy: 1.0000
# Epoch 215, Loss: 0.00, Accuracy: 1.0000
# Epoch 216, Loss: 0.00, Accuracy: 1.0000
# Epoch 217, Loss: 0.00, Accuracy: 1.0000
# Epoch 218, Loss: 0.00, Accuracy: 1.0000
# Epoch 219, Loss: 0.00, Accuracy: 1.0000
# Epoch 220, Loss: 0.00, Accuracy: 1.0000
# Epoch 221, Loss: 0.00, Accuracy: 1.0000
# Epoch 222, Loss: 0.00, Accuracy: 1.0000
# Epoch 223, Loss: 0.00, Accuracy: 1.0000
# Epoch 224, Loss: 0.00, Accuracy: 1.0000
# Epoch 225, Loss: 0.00, Accuracy: 1.0000
# Epoch 226, Loss: 0.00, Accuracy: 1.0000
# Epoch 227, Loss: 0.00, Accuracy: 1.0000
# Epoch 228, Loss: 0.00, Accuracy: 1.0000
# Epoch 229, Loss: 0.00, Accuracy: 1.0000
# Epoch 230, Loss: 0.00, Accuracy: 1.0000
# Epoch 231, Loss: 0.00, Accuracy: 1.0000
# Epoch 232, Loss: 0.00, Accuracy: 1.0000
# Epoch 233, Loss: 0.00, Accuracy: 1.0000
# Epoch 234, Loss: 0.00, Accuracy: 1.0000
# Epoch 235, Loss: 0.00, Accuracy: 1.0000
# Epoch 236, Loss: 0.00, Accuracy: 1.0000
# Epoch 237, Loss: 0.00, Accuracy: 1.0000
# Epoch 238, Loss: 0.00, Accuracy: 1.0000
# Epoch 239, Loss: 0.00, Accuracy: 1.0000
# Epoch 240, Loss: 0.00, Accuracy: 1.0000
# Epoch 241, Loss: 0.00, Accuracy: 1.0000
# Epoch 242, Loss: 0.00, Accuracy: 1.0000
# Epoch 243, Loss: 0.00, Accuracy: 1.0000
# Epoch 244, Loss: 0.00, Accuracy: 1.0000
# Epoch 245, Loss: 0.00, Accuracy: 1.0000
# Epoch 246, Loss: 0.00, Accuracy: 1.0000
# Epoch 247, Loss: 0.00, Accuracy: 1.0000
# Epoch 248, Loss: 0.00, Accuracy: 1.0000
# Epoch 249, Loss: 0.00, Accuracy: 1.0000
# Epoch 250, Loss: 0.00, Accuracy: 1.0000
# Epoch 251, Loss: 0.00, Accuracy: 1.0000
# Epoch 252, Loss: 0.00, Accuracy: 1.0000
# Epoch 253, Loss: 0.00, Accuracy: 1.0000
# Epoch 254, Loss: 0.00, Accuracy: 1.0000
# Epoch 255, Loss: 0.00, Accuracy: 1.0000
# Epoch 256, Loss: 0.00, Accuracy: 1.0000
# Epoch 257, Loss: 0.00, Accuracy: 1.0000
# Epoch 258, Loss: 0.00, Accuracy: 1.0000
# Epoch 259, Loss: 0.00, Accuracy: 1.0000
# Epoch 260, Loss: 0.00, Accuracy: 1.0000
# Epoch 261, Loss: 0.00, Accuracy: 1.0000
# Epoch 262, Loss: 0.00, Accuracy: 1.0000
# Epoch 263, Loss: 0.00, Accuracy: 1.0000
# Epoch 264, Loss: 0.00, Accuracy: 1.0000
# Epoch 265, Loss: 0.00, Accuracy: 1.0000
# Epoch 266, Loss: 0.00, Accuracy: 1.0000
# Epoch 267, Loss: 0.00, Accuracy: 1.0000
# Epoch 268, Loss: 0.00, Accuracy: 1.0000
# Epoch 269, Loss: 0.00, Accuracy: 1.0000
# Epoch 270, Loss: 0.00, Accuracy: 1.0000
# Epoch 271, Loss: 0.00, Accuracy: 1.0000
# Epoch 272, Loss: 0.00, Accuracy: 1.0000
# Epoch 273, Loss: 0.00, Accuracy: 1.0000
# Epoch 274, Loss: 0.00, Accuracy: 1.0000
# Epoch 275, Loss: 0.00, Accuracy: 1.0000
# Epoch 276, Loss: 0.00, Accuracy: 1.0000
# Epoch 277, Loss: 0.00, Accuracy: 1.0000
# Epoch 278, Loss: 0.00, Accuracy: 1.0000
# Epoch 279, Loss: 0.00, Accuracy: 1.0000
# Epoch 280, Loss: 0.00, Accuracy: 1.0000
# Epoch 281, Loss: 0.00, Accuracy: 1.0000
# Epoch 282, Loss: 0.00, Accuracy: 1.0000
# Epoch 283, Loss: 0.00, Accuracy: 1.0000
# Epoch 284, Loss: 0.00, Accuracy: 1.0000
# Epoch 285, Loss: 0.00, Accuracy: 1.0000
# Epoch 286, Loss: 0.00, Accuracy: 1.0000
# Epoch 287, Loss: 0.00, Accuracy: 1.0000
# Epoch 288, Loss: 0.00, Accuracy: 1.0000
# Epoch 289, Loss: 0.00, Accuracy: 1.0000
# Epoch 290, Loss: 0.00, Accuracy: 1.0000
# Epoch 291, Loss: 0.00, Accuracy: 1.0000
# Epoch 292, Loss: 0.00, Accuracy: 1.0000
# Epoch 293, Loss: 0.00, Accuracy: 1.0000
# Epoch 294, Loss: 0.00, Accuracy: 1.0000
# Epoch 295, Loss: 0.00, Accuracy: 1.0000
# Epoch 296, Loss: 0.00, Accuracy: 1.0000
# Epoch 297, Loss: 0.00, Accuracy: 1.0000
# Epoch 298, Loss: 0.00, Accuracy: 1.0000
# Epoch 299, Loss: 0.00, Accuracy: 1.0000
# Epoch 300, Loss: 0.00, Accuracy: 1.0000

# %%
# Test the model

def evaluate(model, dataloader):
    model.eval()
    correct = 0
    preds_list = np.array([])
    actual_list = np.array([])
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.cuda(), labels.cuda()
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            preds_list = np.append(preds_list, preds.item())
            actual_list = np.append(actual_list, torch.argmax(labels, dim=1).item())
            print(f'Predicted: {preds.item()}   True: {torch.argmax(labels, dim=1).item()}')
            correct += (preds == torch.argmax(labels, dim=1)).sum().item()
    return correct / len(dataloader.dataset), preds_list, actual_list

val_acc, preds_list, actual_list = evaluate(model, test_dataloader)
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# Predicted: 1   True: 0
# Predicted: 1   True: 0
# Predicted: 0   True: 1
# Predicted: 1   True: 0
# Predicted: 0   True: 0
# Predicted: 0   True: 1
# Predicted: 0   True: 0
# Predicted: 0   True: 1
# Predicted: 0   True: 1
# Predicted: 0   True: 1
# Validation Accuracy: 0.2000

# %%
reg_vals = np.load('data/y_TEST_RAW_REG.npy')
thresh = 8

for i in range(len(reg_vals)):
    if preds_list[i] == 0:
        plt.plot((i+1), reg_vals[i], 'o', color='red')
    else:
        plt.plot((i+1), reg_vals[i], 'o', color='green')

plt.axhline(y=thresh, color='grey', linestyle='--', linewidth=2, label=f'Threshold at y={thresh}')

# Add labels and title
plt.xlabel("Subjects")
plt.ylabel("Mood Score Change WR -> SD")
plt.title("Predictive Results")

plt.legend()
plt.show()
