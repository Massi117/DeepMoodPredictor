# %% [markdown]
# # Using a VAE to expand the training data

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import sklearn
from sklearn. model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest, f_classif

import matplotlib.pyplot as plt # For data viz
import pandas as pd
import numpy as np
import sys

print('System Version:', sys.version)
print('PyTorch version', torch.__version__)
print('CUDA version', torch.version.cuda)
print('Numpy version', np.__version__)
print('Pandas version', pd.__version__)
print('Sklearn version', sklearn.__version__)
# Out:
# System Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version 2.5.1
# CUDA version 12.4
# Numpy version 1.26.4
# Pandas version 2.2.3
# Sklearn version 1.6.0

# %%
# Confirm device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
try: 
    name = torch.cuda.get_device_name(0)
    count = torch.cuda.device_count()
    print(f"Device count: {count}")
    print(f"Device name: {name}")
except RuntimeError:
    print('No GPUs detected')
# Out:
# Using cuda device
# Device count: 1
# Device name: NVIDIA L40S

# %%
# Load the data
X = np.load('data/X_TRAIN_RAW.npy')
y = np.load('data/y_TRAIN_RAW.npy')

# %%
# Define the dataset
class COPEDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        cope_data = self.data[index]
        cope_data = (cope_data - np.min(cope_data)) / (np.max(cope_data) - np.min(cope_data))  # normalize

        label = self.target[index]
        volume = torch.tensor(cope_data, dtype=torch.float32).unsqueeze(0)  # (1, 91, 109, 91)
        label = torch.tensor([1.0, 0.0] if label == 0 else [0.0, 1.0], dtype=torch.float32)
        return volume, label

# %%
# Initiate the dataset and data loader
dataset = COPEDataset(X, y)
dataloader = DataLoader(dataset, batch_size=4)

# %% [markdown]
# Creating an autoencoder to generate more data

# %%
# Define the model
class CVAE3D(nn.Module):
    def __init__(self, latent_dim=128, label_dim=2, label_embed_dim=16):
        super(CVAE3D, self).__init__()
        self.latent_dim = latent_dim
        self.label_dim = label_dim

        # Embed the label into a dense vector
        self.label_embedding = nn.Linear(label_dim, label_embed_dim)

        # Encoder
        self.encoder_conv = nn.Sequential(
            nn.Conv3d(1, 16, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm3d(16),
            nn.ReLU(),

        )

        # Calculate the size of the flattened layer dynamically
        # We run a dummy tensor through the conv/pool layers to find the shape
        self.flatten_dim = None
        self.min_dim = None
        self._get_conv_output((1, 23, 19, 15)) # Dummy run to calculate self._to_linear

        print(self.flatten_dim)
        print(self.min_dim)

        self.encoder_fc_mu = nn.Linear(self.flatten_dim + label_embed_dim, latent_dim)
        self.encoder_fc_logvar = nn.Linear(self.flatten_dim + label_embed_dim, latent_dim)

        # Decoder
        self.decoder_fc = nn.Linear(latent_dim + label_embed_dim, self.flatten_dim)

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose3d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def _get_conv_output(self, shape):
        """Helper function to calculate the input size for the fully connected layers."""
        # Create a dummy input tensor with batch size 1
        dummy_input = torch.rand(1, *shape) 
        output_features = self.encoder_conv(dummy_input)
        # Store the calculated size
        self.flatten_dim = output_features.view(output_features.size(0), -1).size(1)
        self.min_dim = output_features.shape

    
    def encode(self, x, labels):
        x = self.encoder_conv(x)
        x = x.view(x.size(0), -1)
        labels = self.label_embedding(labels)
        x = torch.cat([x, labels], dim=1)
        mu = self.encoder_fc_mu(x)
        logvar = self.encoder_fc_logvar(x)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z, labels):
        labels = self.label_embedding(labels)
        z = torch.cat([z, labels], dim=1)
        x = self.decoder_fc(z)
        x = x.view(-1, 16, 5, 4, 4)
        x = self.decoder_conv(x)
        # Crop to original shape
        x = x[:, :, :23, :19, :15]
        return x

    def forward(self, x, labels):
        mu, logvar = self.encode(x, labels)
        z = self.reparameterize(mu, logvar)
        recon = self.decode(z, labels)
        return recon, mu, logvar

# %%
# Define the loss
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    kld = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kld

# %%
# Train the model
model = CVAE3D(latent_dim=128).cuda()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

for epoch in range(30):
    model.train()
    total_loss = 0
    for batch in dataloader:
        volumes, labels = batch
        volumes, labels = volumes.cuda(), labels.cuda()

        optimizer.zero_grad()
        recon, mu, logvar = model(volumes, labels)
        loss = vae_loss(recon, volumes, mu, logvar)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader)}")
# Out:
# 1280
# torch.Size([1, 16, 5, 4, 4])
# Epoch 1, Loss: 145.67093658447266
# Epoch 2, Loss: 123.98710038926866
# Epoch 3, Loss: 121.16567484537761
# Epoch 4, Loss: 118.48729960123698
# Epoch 5, Loss: 114.86731211344402
# Epoch 6, Loss: 113.19648996988933
# Epoch 7, Loss: 112.18529256184895
# Epoch 8, Loss: 110.75551859537761
# Epoch 9, Loss: 110.0108405219184
# Epoch 10, Loss: 108.85653898451064
# Epoch 11, Loss: 108.55058966742621
# Epoch 12, Loss: 108.54929818047418
# Epoch 13, Loss: 107.89935514662001
# Epoch 14, Loss: 107.4641973707411
# Epoch 15, Loss: 106.14699215359158
# Epoch 16, Loss: 105.61040581597223
# Epoch 17, Loss: 105.64522043863933
# Epoch 18, Loss: 104.81863191392686
# Epoch 19, Loss: 103.63469314575195
# Epoch 20, Loss: 103.8680771721734
# Epoch 21, Loss: 103.40898513793945
# Epoch 22, Loss: 102.73618189493816
# Epoch 23, Loss: 101.91496870252821
# Epoch 24, Loss: 100.90865707397461
# Epoch 25, Loss: 101.32738749186198
# Epoch 26, Loss: 101.50817447238498
# Epoch 27, Loss: 101.07666820949979
# Epoch 28, Loss: 100.34803899129231
# Epoch 29, Loss: 100.49482599894206
# Epoch 30, Loss: 100.11129548814561

# %%
# Generate synthetic data
n = 500
NEW_X = torch.empty((n*2,10,7,8), device=device)
NEW_y = y
model.eval()

# Generating 40 * 3 new samples (120 samples: 60 of each group)
# Group 0
print('Group 0:')
for i in range(n):
    with torch.no_grad():
        z = torch.randn(1, 128).cuda()

        group_label = torch.tensor([[1.0, 0.0]]).cuda()  # one-hot
        synthetic = model.decode(z, group_label)  # (1, 1, 91, 109, 91)
        synthetic = torch.squeeze(synthetic)
    
        NEW_X[i] = synthetic #, synthetic, axis=0)
        NEW_y = np.append(NEW_y, [0], axis=0)
        print(f'Generated sample {i+1}/{n}')

# Group 1
print('Group 1:')
for i in range(n):
    with torch.no_grad():
        z = torch.randn(1, 128).cuda()

        group_label = torch.tensor([[0.0, 1.0]]).cuda()  # one-hot
        synthetic = model.decode(z, group_label)  # (1, 1, 91, 109, 91)
        synthetic = torch.squeeze(synthetic)
    
    NEW_X[i+n] = synthetic #NEW_X = np.append(NEW_X, synthetic, axis=0)
    NEW_y = np.append(NEW_y, [1], axis=0)
    print(f'Generated sample {i+1}/{n}')

Syn_X = NEW_X.cpu().numpy()
NEW_X = np.append(X, Syn_X, axis=0)
# Out:
# Group 0:
# Generated sample 1/500
# Generated sample 2/500
# Generated sample 3/500
# Generated sample 4/500
# Generated sample 5/500
# Generated sample 6/500
# Generated sample 7/500
# Generated sample 8/500
# Generated sample 9/500
# Generated sample 10/500
# Generated sample 11/500
# Generated sample 12/500
# Generated sample 13/500
# Generated sample 14/500
# Generated sample 15/500
# Generated sample 16/500
# Generated sample 17/500
# Generated sample 18/500
# Generated sample 19/500
# Generated sample 20/500
# Generated sample 21/500
# Generated sample 22/500
# Generated sample 23/500
# Generated sample 24/500
# Generated sample 25/500
# Generated sample 26/500
# Generated sample 27/500
# Generated sample 28/500
# Generated sample 29/500
# Generated sample 30/500
# Generated sample 31/500
# Generated sample 32/500
# Generated sample 33/500
# Generated sample 34/500
# Generated sample 35/500
# Generated sample 36/500
# Generated sample 37/500
# Generated sample 38/500
# Generated sample 39/500
# Generated sample 40/500
# Generated sample 41/500
# Generated sample 42/500
# Generated sample 43/500
# Generated sample 44/500
# Generated sample 45/500
# Generated sample 46/500
# Generated sample 47/500
# Generated sample 48/500
# Generated sample 49/500
# Generated sample 50/500
# Generated sample 51/500
# Generated sample 52/500
# Generated sample 53/500
# Generated sample 54/500
# Generated sample 55/500
# Generated sample 56/500
# Generated sample 57/500
# Generated sample 58/500
# Generated sample 59/500
# Generated sample 60/500
# Generated sample 61/500
# Generated sample 62/500
# Generated sample 63/500
# Generated sample 64/500
# Generated sample 65/500
# Generated sample 66/500
# Generated sample 67/500
# Generated sample 68/500
# Generated sample 69/500
# Generated sample 70/500
# Generated sample 71/500
# Generated sample 72/500
# Generated sample 73/500
# Generated sample 74/500
# Generated sample 75/500
# Generated sample 76/500
# Generated sample 77/500
# Generated sample 78/500
# Generated sample 79/500
# Generated sample 80/500
# Generated sample 81/500
# Generated sample 82/500
# Generated sample 83/500
# Generated sample 84/500
# Generated sample 85/500
# Generated sample 86/500
# Generated sample 87/500
# Generated sample 88/500
# Generated sample 89/500
# Generated sample 90/500
# Generated sample 91/500
# Generated sample 92/500
# Generated sample 93/500
# Generated sample 94/500
# Generated sample 95/500
# Generated sample 96/500
# Generated sample 97/500
# Generated sample 98/500
# Generated sample 99/500
# Generated sample 100/500
# Generated sample 101/500
# Generated sample 102/500
# Generated sample 103/500
# Generated sample 104/500
# Generated sample 105/500
# Generated sample 106/500
# Generated sample 107/500
# Generated sample 108/500
# Generated sample 109/500
# Generated sample 110/500
# Generated sample 111/500
# Generated sample 112/500
# Generated sample 113/500
# Generated sample 114/500
# Generated sample 115/500
# Generated sample 116/500
# Generated sample 117/500
# Generated sample 118/500
# Generated sample 119/500
# Generated sample 120/500
# Generated sample 121/500
# Generated sample 122/500
# Generated sample 123/500
# Generated sample 124/500
# Generated sample 125/500
# Generated sample 126/500
# Generated sample 127/500
# Generated sample 128/500
# Generated sample 129/500
# Generated sample 130/500
# Generated sample 131/500
# Generated sample 132/500
# Generated sample 133/500
# Generated sample 134/500
# Generated sample 135/500
# Generated sample 136/500
# Generated sample 137/500
# Generated sample 138/500
# Generated sample 139/500
# Generated sample 140/500
# Generated sample 141/500
# Generated sample 142/500
# Generated sample 143/500
# Generated sample 144/500
# Generated sample 145/500
# Generated sample 146/500
# Generated sample 147/500
# Generated sample 148/500
# Generated sample 149/500
# Generated sample 150/500
# Generated sample 151/500
# Generated sample 152/500
# Generated sample 153/500
# Generated sample 154/500
# Generated sample 155/500
# Generated sample 156/500
# Generated sample 157/500
# Generated sample 158/500
# Generated sample 159/500
# Generated sample 160/500
# Generated sample 161/500
# Generated sample 162/500
# Generated sample 163/500
# Generated sample 164/500
# Generated sample 165/500
# Generated sample 166/500
# Generated sample 167/500
# Generated sample 168/500
# Generated sample 169/500
# Generated sample 170/500
# Generated sample 171/500
# Generated sample 172/500
# Generated sample 173/500
# Generated sample 174/500
# Generated sample 175/500
# Generated sample 176/500
# Generated sample 177/500
# Generated sample 178/500
# Generated sample 179/500
# Generated sample 180/500
# Generated sample 181/500
# Generated sample 182/500
# Generated sample 183/500
# Generated sample 184/500
# Generated sample 185/500
# Generated sample 186/500
# Generated sample 187/500
# Generated sample 188/500
# Generated sample 189/500
# Generated sample 190/500
# Generated sample 191/500
# Generated sample 192/500
# Generated sample 193/500
# Generated sample 194/500
# Generated sample 195/500
# Generated sample 196/500
# Generated sample 197/500
# Generated sample 198/500
# Generated sample 199/500
# Generated sample 200/500
# Generated sample 201/500
# Generated sample 202/500
# Generated sample 203/500
# Generated sample 204/500
# Generated sample 205/500
# Generated sample 206/500
# Generated sample 207/500
# Generated sample 208/500
# Generated sample 209/500
# Generated sample 210/500
# Generated sample 211/500
# Generated sample 212/500
# Generated sample 213/500
# Generated sample 214/500
# Generated sample 215/500
# Generated sample 216/500
# Generated sample 217/500
# Generated sample 218/500
# Generated sample 219/500
# Generated sample 220/500
# Generated sample 221/500
# Generated sample 222/500
# Generated sample 223/500
# Generated sample 224/500
# Generated sample 225/500
# Generated sample 226/500
# Generated sample 227/500
# Generated sample 228/500
# Generated sample 229/500
# Generated sample 230/500
# Generated sample 231/500
# Generated sample 232/500
# Generated sample 233/500
# Generated sample 234/500
# Generated sample 235/500
# Generated sample 236/500
# Generated sample 237/500
# Generated sample 238/500
# Generated sample 239/500
# Generated sample 240/500
# Generated sample 241/500
# Generated sample 242/500
# Generated sample 243/500
# Generated sample 244/500
# Generated sample 245/500
# Generated sample 246/500
# Generated sample 247/500
# Generated sample 248/500
# Generated sample 249/500
# Generated sample 250/500
# Generated sample 251/500
# Generated sample 252/500
# Generated sample 253/500
# Generated sample 254/500
# Generated sample 255/500
# Generated sample 256/500
# Generated sample 257/500
# Generated sample 258/500
# Generated sample 259/500
# Generated sample 260/500
# Generated sample 261/500
# Generated sample 262/500
# Generated sample 263/500
# Generated sample 264/500
# Generated sample 265/500
# Generated sample 266/500
# Generated sample 267/500
# Generated sample 268/500
# Generated sample 269/500
# Generated sample 270/500
# Generated sample 271/500
# Generated sample 272/500
# Generated sample 273/500
# Generated sample 274/500
# Generated sample 275/500
# Generated sample 276/500
# Generated sample 277/500
# Generated sample 278/500
# Generated sample 279/500
# Generated sample 280/500
# Generated sample 281/500
# Generated sample 282/500
# Generated sample 283/500
# Generated sample 284/500
# Generated sample 285/500
# Generated sample 286/500
# Generated sample 287/500
# Generated sample 288/500
# Generated sample 289/500
# Generated sample 290/500
# Generated sample 291/500
# Generated sample 292/500
# Generated sample 293/500
# Generated sample 294/500
# Generated sample 295/500
# Generated sample 296/500
# Generated sample 297/500
# Generated sample 298/500
# Generated sample 299/500
# Generated sample 300/500
# Generated sample 301/500
# Generated sample 302/500
# Generated sample 303/500
# Generated sample 304/500
# Generated sample 305/500
# Generated sample 306/500
# Generated sample 307/500
# Generated sample 308/500
# Generated sample 309/500
# Generated sample 310/500
# Generated sample 311/500
# Generated sample 312/500
# Generated sample 313/500
# Generated sample 314/500
# Generated sample 315/500
# Generated sample 316/500
# Generated sample 317/500
# Generated sample 318/500
# Generated sample 319/500
# Generated sample 320/500
# Generated sample 321/500
# Generated sample 322/500
# Generated sample 323/500
# Generated sample 324/500
# Generated sample 325/500
# Generated sample 326/500
# Generated sample 327/500
# Generated sample 328/500
# Generated sample 329/500
# Generated sample 330/500
# Generated sample 331/500
# Generated sample 332/500
# Generated sample 333/500
# Generated sample 334/500
# Generated sample 335/500
# Generated sample 336/500
# Generated sample 337/500
# Generated sample 338/500
# Generated sample 339/500
# Generated sample 340/500
# Generated sample 341/500
# Generated sample 342/500
# Generated sample 343/500
# Generated sample 344/500
# Generated sample 345/500
# Generated sample 346/500
# Generated sample 347/500
# Generated sample 348/500
# Generated sample 349/500
# Generated sample 350/500
# Generated sample 351/500
# Generated sample 352/500
# Generated sample 353/500
# Generated sample 354/500
# Generated sample 355/500
# Generated sample 356/500
# Generated sample 357/500
# Generated sample 358/500
# Generated sample 359/500
# Generated sample 360/500
# Generated sample 361/500
# Generated sample 362/500
# Generated sample 363/500
# Generated sample 364/500
# Generated sample 365/500
# Generated sample 366/500
# Generated sample 367/500
# Generated sample 368/500
# Generated sample 369/500
# Generated sample 370/500
# Generated sample 371/500
# Generated sample 372/500
# Generated sample 373/500
# Generated sample 374/500
# Generated sample 375/500
# Generated sample 376/500
# Generated sample 377/500
# Generated sample 378/500
# Generated sample 379/500
# Generated sample 380/500
# Generated sample 381/500
# Generated sample 382/500
# Generated sample 383/500
# Generated sample 384/500
# Generated sample 385/500
# Generated sample 386/500
# Generated sample 387/500
# Generated sample 388/500
# Generated sample 389/500
# Generated sample 390/500
# Generated sample 391/500
# Generated sample 392/500
# Generated sample 393/500
# Generated sample 394/500
# Generated sample 395/500
# Generated sample 396/500
# Generated sample 397/500
# Generated sample 398/500
# Generated sample 399/500
# Generated sample 400/500
# Generated sample 401/500
# Generated sample 402/500
# Generated sample 403/500
# Generated sample 404/500
# Generated sample 405/500
# Generated sample 406/500
# Generated sample 407/500
# Generated sample 408/500
# Generated sample 409/500
# Generated sample 410/500
# Generated sample 411/500
# Generated sample 412/500
# Generated sample 413/500
# Generated sample 414/500
# Generated sample 415/500
# Generated sample 416/500
# Generated sample 417/500
# Generated sample 418/500
# Generated sample 419/500
# Generated sample 420/500
# Generated sample 421/500
# Generated sample 422/500
# Generated sample 423/500
# Generated sample 424/500
# Generated sample 425/500
# Generated sample 426/500
# Generated sample 427/500
# Generated sample 428/500
# Generated sample 429/500
# Generated sample 430/500
# Generated sample 431/500
# Generated sample 432/500
# Generated sample 433/500
# Generated sample 434/500
# Generated sample 435/500
# Generated sample 436/500
# Generated sample 437/500
# Generated sample 438/500
# Generated sample 439/500
# Generated sample 440/500
# Generated sample 441/500
# Generated sample 442/500
# Generated sample 443/500
# Generated sample 444/500
# Generated sample 445/500
# Generated sample 446/500
# Generated sample 447/500
# Generated sample 448/500
# Generated sample 449/500
# Generated sample 450/500
# Generated sample 451/500
# Generated sample 452/500
# Generated sample 453/500
# Generated sample 454/500
# Generated sample 455/500
# Generated sample 456/500
# Generated sample 457/500
# Generated sample 458/500
# Generated sample 459/500
# Generated sample 460/500
# Generated sample 461/500
# Generated sample 462/500
# Generated sample 463/500
# Generated sample 464/500
# Generated sample 465/500
# Generated sample 466/500
# Generated sample 467/500
# Generated sample 468/500
# Generated sample 469/500
# Generated sample 470/500
# Generated sample 471/500
# Generated sample 472/500
# Generated sample 473/500
# Generated sample 474/500
# Generated sample 475/500
# Generated sample 476/500
# Generated sample 477/500
# Generated sample 478/500
# Generated sample 479/500
# Generated sample 480/500
# Generated sample 481/500
# Generated sample 482/500
# Generated sample 483/500
# Generated sample 484/500
# Generated sample 485/500
# Generated sample 486/500
# Generated sample 487/500
# Generated sample 488/500
# Generated sample 489/500
# Generated sample 490/500
# Generated sample 491/500
# Generated sample 492/500
# Generated sample 493/500
# Generated sample 494/500
# Generated sample 495/500
# Generated sample 496/500
# Generated sample 497/500
# Generated sample 498/500
# Generated sample 499/500
# Generated sample 500/500
# Group 1:
# Generated sample 1/500
# Generated sample 2/500
# Generated sample 3/500
# Generated sample 4/500
# Generated sample 5/500
# Generated sample 6/500
# Generated sample 7/500
# Generated sample 8/500
# Generated sample 9/500
# Generated sample 10/500
# Generated sample 11/500
# Generated sample 12/500
# Generated sample 13/500
# Generated sample 14/500
# Generated sample 15/500
# Generated sample 16/500
# Generated sample 17/500
# Generated sample 18/500
# Generated sample 19/500
# Generated sample 20/500
# Generated sample 21/500
# Generated sample 22/500
# Generated sample 23/500
# Generated sample 24/500
# Generated sample 25/500
# Generated sample 26/500
# Generated sample 27/500
# Generated sample 28/500
# Generated sample 29/500
# Generated sample 30/500
# Generated sample 31/500
# Generated sample 32/500
# Generated sample 33/500
# Generated sample 34/500
# Generated sample 35/500
# Generated sample 36/500
# Generated sample 37/500
# Generated sample 38/500
# Generated sample 39/500
# Generated sample 40/500
# Generated sample 41/500
# Generated sample 42/500
# Generated sample 43/500
# Generated sample 44/500
# Generated sample 45/500
# Generated sample 46/500
# Generated sample 47/500
# Generated sample 48/500
# Generated sample 49/500
# Generated sample 50/500
# Generated sample 51/500
# Generated sample 52/500
# Generated sample 53/500
# Generated sample 54/500
# Generated sample 55/500
# Generated sample 56/500
# Generated sample 57/500
# Generated sample 58/500
# Generated sample 59/500
# Generated sample 60/500
# Generated sample 61/500
# Generated sample 62/500
# Generated sample 63/500
# Generated sample 64/500
# Generated sample 65/500
# Generated sample 66/500
# Generated sample 67/500
# Generated sample 68/500
# Generated sample 69/500
# Generated sample 70/500
# Generated sample 71/500
# Generated sample 72/500
# Generated sample 73/500
# Generated sample 74/500
# Generated sample 75/500
# Generated sample 76/500
# Generated sample 77/500
# Generated sample 78/500
# Generated sample 79/500
# Generated sample 80/500
# Generated sample 81/500
# Generated sample 82/500
# Generated sample 83/500
# Generated sample 84/500
# Generated sample 85/500
# Generated sample 86/500
# Generated sample 87/500
# Generated sample 88/500
# Generated sample 89/500
# Generated sample 90/500
# Generated sample 91/500
# Generated sample 92/500
# Generated sample 93/500
# Generated sample 94/500
# Generated sample 95/500
# Generated sample 96/500
# Generated sample 97/500
# Generated sample 98/500
# Generated sample 99/500
# Generated sample 100/500
# Generated sample 101/500
# Generated sample 102/500
# Generated sample 103/500
# Generated sample 104/500
# Generated sample 105/500
# Generated sample 106/500
# Generated sample 107/500
# Generated sample 108/500
# Generated sample 109/500
# Generated sample 110/500
# Generated sample 111/500
# Generated sample 112/500
# Generated sample 113/500
# Generated sample 114/500
# Generated sample 115/500
# Generated sample 116/500
# Generated sample 117/500
# Generated sample 118/500
# Generated sample 119/500
# Generated sample 120/500
# Generated sample 121/500
# Generated sample 122/500
# Generated sample 123/500
# Generated sample 124/500
# Generated sample 125/500
# Generated sample 126/500
# Generated sample 127/500
# Generated sample 128/500
# Generated sample 129/500
# Generated sample 130/500
# Generated sample 131/500
# Generated sample 132/500
# Generated sample 133/500
# Generated sample 134/500
# Generated sample 135/500
# Generated sample 136/500
# Generated sample 137/500
# Generated sample 138/500
# Generated sample 139/500
# Generated sample 140/500
# Generated sample 141/500
# Generated sample 142/500
# Generated sample 143/500
# Generated sample 144/500
# Generated sample 145/500
# Generated sample 146/500
# Generated sample 147/500
# Generated sample 148/500
# Generated sample 149/500
# Generated sample 150/500
# Generated sample 151/500
# Generated sample 152/500
# Generated sample 153/500
# Generated sample 154/500
# Generated sample 155/500
# Generated sample 156/500
# Generated sample 157/500
# Generated sample 158/500
# Generated sample 159/500
# Generated sample 160/500
# Generated sample 161/500
# Generated sample 162/500
# Generated sample 163/500
# Generated sample 164/500
# Generated sample 165/500
# Generated sample 166/500
# Generated sample 167/500
# Generated sample 168/500
# Generated sample 169/500
# Generated sample 170/500
# Generated sample 171/500
# Generated sample 172/500
# Generated sample 173/500
# Generated sample 174/500
# Generated sample 175/500
# Generated sample 176/500
# Generated sample 177/500
# Generated sample 178/500
# Generated sample 179/500
# Generated sample 180/500
# Generated sample 181/500
# Generated sample 182/500
# Generated sample 183/500
# Generated sample 184/500
# Generated sample 185/500
# Generated sample 186/500
# Generated sample 187/500
# Generated sample 188/500
# Generated sample 189/500
# Generated sample 190/500
# Generated sample 191/500
# Generated sample 192/500
# Generated sample 193/500
# Generated sample 194/500
# Generated sample 195/500
# Generated sample 196/500
# Generated sample 197/500
# Generated sample 198/500
# Generated sample 199/500
# Generated sample 200/500
# Generated sample 201/500
# Generated sample 202/500
# Generated sample 203/500
# Generated sample 204/500
# Generated sample 205/500
# Generated sample 206/500
# Generated sample 207/500
# Generated sample 208/500
# Generated sample 209/500
# Generated sample 210/500
# Generated sample 211/500
# Generated sample 212/500
# Generated sample 213/500
# Generated sample 214/500
# Generated sample 215/500
# Generated sample 216/500
# Generated sample 217/500
# Generated sample 218/500
# Generated sample 219/500
# Generated sample 220/500
# Generated sample 221/500
# Generated sample 222/500
# Generated sample 223/500
# Generated sample 224/500
# Generated sample 225/500
# Generated sample 226/500
# Generated sample 227/500
# Generated sample 228/500
# Generated sample 229/500
# Generated sample 230/500
# Generated sample 231/500
# Generated sample 232/500
# Generated sample 233/500
# Generated sample 234/500
# Generated sample 235/500
# Generated sample 236/500
# Generated sample 237/500
# Generated sample 238/500
# Generated sample 239/500
# Generated sample 240/500
# Generated sample 241/500
# Generated sample 242/500
# Generated sample 243/500
# Generated sample 244/500
# Generated sample 245/500
# Generated sample 246/500
# Generated sample 247/500
# Generated sample 248/500
# Generated sample 249/500
# Generated sample 250/500
# Generated sample 251/500
# Generated sample 252/500
# Generated sample 253/500
# Generated sample 254/500
# Generated sample 255/500
# Generated sample 256/500
# Generated sample 257/500
# Generated sample 258/500
# Generated sample 259/500
# Generated sample 260/500
# Generated sample 261/500
# Generated sample 262/500
# Generated sample 263/500
# Generated sample 264/500
# Generated sample 265/500
# Generated sample 266/500
# Generated sample 267/500
# Generated sample 268/500
# Generated sample 269/500
# Generated sample 270/500
# Generated sample 271/500
# Generated sample 272/500
# Generated sample 273/500
# Generated sample 274/500
# Generated sample 275/500
# Generated sample 276/500
# Generated sample 277/500
# Generated sample 278/500
# Generated sample 279/500
# Generated sample 280/500
# Generated sample 281/500
# Generated sample 282/500
# Generated sample 283/500
# Generated sample 284/500
# Generated sample 285/500
# Generated sample 286/500
# Generated sample 287/500
# Generated sample 288/500
# Generated sample 289/500
# Generated sample 290/500
# Generated sample 291/500
# Generated sample 292/500
# Generated sample 293/500
# Generated sample 294/500
# Generated sample 295/500
# Generated sample 296/500
# Generated sample 297/500
# Generated sample 298/500
# Generated sample 299/500
# Generated sample 300/500
# Generated sample 301/500
# Generated sample 302/500
# Generated sample 303/500
# Generated sample 304/500
# Generated sample 305/500
# Generated sample 306/500
# Generated sample 307/500
# Generated sample 308/500
# Generated sample 309/500
# Generated sample 310/500
# Generated sample 311/500
# Generated sample 312/500
# Generated sample 313/500
# Generated sample 314/500
# Generated sample 315/500
# Generated sample 316/500
# Generated sample 317/500
# Generated sample 318/500
# Generated sample 319/500
# Generated sample 320/500
# Generated sample 321/500
# Generated sample 322/500
# Generated sample 323/500
# Generated sample 324/500
# Generated sample 325/500
# Generated sample 326/500
# Generated sample 327/500
# Generated sample 328/500
# Generated sample 329/500
# Generated sample 330/500
# Generated sample 331/500
# Generated sample 332/500
# Generated sample 333/500
# Generated sample 334/500
# Generated sample 335/500
# Generated sample 336/500
# Generated sample 337/500
# Generated sample 338/500
# Generated sample 339/500
# Generated sample 340/500
# Generated sample 341/500
# Generated sample 342/500
# Generated sample 343/500
# Generated sample 344/500
# Generated sample 345/500
# Generated sample 346/500
# Generated sample 347/500
# Generated sample 348/500
# Generated sample 349/500
# Generated sample 350/500
# Generated sample 351/500
# Generated sample 352/500
# Generated sample 353/500
# Generated sample 354/500
# Generated sample 355/500
# Generated sample 356/500
# Generated sample 357/500
# Generated sample 358/500
# Generated sample 359/500
# Generated sample 360/500
# Generated sample 361/500
# Generated sample 362/500
# Generated sample 363/500
# Generated sample 364/500
# Generated sample 365/500
# Generated sample 366/500
# Generated sample 367/500
# Generated sample 368/500
# Generated sample 369/500
# Generated sample 370/500
# Generated sample 371/500
# Generated sample 372/500
# Generated sample 373/500
# Generated sample 374/500
# Generated sample 375/500
# Generated sample 376/500
# Generated sample 377/500
# Generated sample 378/500
# Generated sample 379/500
# Generated sample 380/500
# Generated sample 381/500
# Generated sample 382/500
# Generated sample 383/500
# Generated sample 384/500
# Generated sample 385/500
# Generated sample 386/500
# Generated sample 387/500
# Generated sample 388/500
# Generated sample 389/500
# Generated sample 390/500
# Generated sample 391/500
# Generated sample 392/500
# Generated sample 393/500
# Generated sample 394/500
# Generated sample 395/500
# Generated sample 396/500
# Generated sample 397/500
# Generated sample 398/500
# Generated sample 399/500
# Generated sample 400/500
# Generated sample 401/500
# Generated sample 402/500
# Generated sample 403/500
# Generated sample 404/500
# Generated sample 405/500
# Generated sample 406/500
# Generated sample 407/500
# Generated sample 408/500
# Generated sample 409/500
# Generated sample 410/500
# Generated sample 411/500
# Generated sample 412/500
# Generated sample 413/500
# Generated sample 414/500
# Generated sample 415/500
# Generated sample 416/500
# Generated sample 417/500
# Generated sample 418/500
# Generated sample 419/500
# Generated sample 420/500
# Generated sample 421/500
# Generated sample 422/500
# Generated sample 423/500
# Generated sample 424/500
# Generated sample 425/500
# Generated sample 426/500
# Generated sample 427/500
# Generated sample 428/500
# Generated sample 429/500
# Generated sample 430/500
# Generated sample 431/500
# Generated sample 432/500
# Generated sample 433/500
# Generated sample 434/500
# Generated sample 435/500
# Generated sample 436/500
# Generated sample 437/500
# Generated sample 438/500
# Generated sample 439/500
# Generated sample 440/500
# Generated sample 441/500
# Generated sample 442/500
# Generated sample 443/500
# Generated sample 444/500
# Generated sample 445/500
# Generated sample 446/500
# Generated sample 447/500
# Generated sample 448/500
# Generated sample 449/500
# Generated sample 450/500
# Generated sample 451/500
# Generated sample 452/500
# Generated sample 453/500
# Generated sample 454/500
# Generated sample 455/500
# Generated sample 456/500
# Generated sample 457/500
# Generated sample 458/500
# Generated sample 459/500
# Generated sample 460/500
# Generated sample 461/500
# Generated sample 462/500
# Generated sample 463/500
# Generated sample 464/500
# Generated sample 465/500
# Generated sample 466/500
# Generated sample 467/500
# Generated sample 468/500
# Generated sample 469/500
# Generated sample 470/500
# Generated sample 471/500
# Generated sample 472/500
# Generated sample 473/500
# Generated sample 474/500
# Generated sample 475/500
# Generated sample 476/500
# Generated sample 477/500
# Generated sample 478/500
# Generated sample 479/500
# Generated sample 480/500
# Generated sample 481/500
# Generated sample 482/500
# Generated sample 483/500
# Generated sample 484/500
# Generated sample 485/500
# Generated sample 486/500
# Generated sample 487/500
# Generated sample 488/500
# Generated sample 489/500
# Generated sample 490/500
# Generated sample 491/500
# Generated sample 492/500
# Generated sample 493/500
# Generated sample 494/500
# Generated sample 495/500
# Generated sample 496/500
# Generated sample 497/500
# Generated sample 498/500
# Generated sample 499/500
# Generated sample 500/500

# %%
# Confirm additions
print(NEW_X.shape)
print(NEW_y.shape)
# Out:
# (1035, 10, 7, 8)
# (1035,)

# %%
# Save the new data
np.save('data/X_SYN.npy', NEW_X)
np.save('data/y_SYN.npy', NEW_y)
